# %%
import pandas as pd

# %%
# !wget "https://drive.google.com/uc?export=download&id=1E3bwvYGf1iWc0IXPN-mD bI "  -O "mcknisey.csv"
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
df=pd.read_csv("a.csv")
df.sort_values(by="Dept")
# Out:
#     ID     Name  Age Gender       City  Salary     Dept  Experience  Rating  \
# 13  14    Anita   32      F       Pune   55000  Finance           8     4.4
# 23  24    Divya   27      F    Chennai   45000  Finance           5     4.0
# 29  30     Alka   26      F    Chennai   44000  Finance           4     4.1
# 20  21   Rakesh   37      M      Delhi   72000  Finance          11     4.8
# 38  39    Vinay   38      M      Delhi   77000  Finance          13     4.9
# 17  18   Shreya   26      F    Chennai   43000  Finance           4     4.1
# 32  33     Ajay   36      M      Delhi   74000  Finance          12     4.8
# 10  11   Deepak   36      M  Bangalore   75000  Finance          12     4.9
# 26  27      Raj   39      M      Delhi   78000  Finance          14     4.9
# 35  36  Pallavi   29      F    Chennai   48000  Finance           6     4.3
# 6    7     Anil   31      M    Chennai   52000  Finance           7     4.3
# ...

# %%
df.head()
# Out:
#    ID   Name  Age Gender       City  Salary     Dept  Experience  Rating  \
# 0   1   Amit   25      M      Delhi   40000       IT           2     4.2
# 1   2   Ravi   30      M     Mumbai   50000       HR           5     3.8
# 2   3   Sita   28      F       Pune   45000  Finance           4     4.5
# 3   4   Neha   26      F      Delhi   42000       IT           3     4.0
# 4   5  Rohan   35      M  Bangalore   70000       IT          10     4.8
#
#    Projects  Hours  Bonus  Status  JoinYear  LastProm  Leaves  Score Team  \
# 0         3    160   5000  Active      2022      2023       5     78    A
# 1         5    170   7000  Active      2020      2022       8     82    B
# 2         4    165   6000  Active      2021      2023       6     85    A
# 3         2    150   4000  Active      2022      2023       4     75    C
# 4         6    180  10000  Active      2018      2022      10     90    A
#
#   Manager Country
# 0     Yes   India
# 1      No   India
# 2     Yes   India
# ...

# %%
import numpy as np

# %%
df["Age"].value_counts()
# Out:
# Age
# 28    4
# 27    4
# 26    4
# 29    4
# 25    3
# 31    3
# 30    2
# 35    2
# 33    2
# 24    2
# 36    2
# 32    2
# 34    2
# 40    1
# 37    1
# 39    1
# 38    1
# Name: count, dtype: int64

# %%
df.drop("Age",axis=1)
# Out:
#     ID     Name Gender       City  Salary     Dept  Experience  Rating  \
# 0    1     Amit      M      Delhi   40000       IT           2     4.2
# 1    2     Ravi      M     Mumbai   50000       HR           5     3.8
# 2    3     Sita      F       Pune   45000  Finance           4     4.5
# 3    4     Neha      F      Delhi   42000       IT           3     4.0
# 4    5    Rohan      M  Bangalore   70000       IT          10     4.8
# 5    6    Kiran      F  Hyderabad   48000       HR           6     3.9
# 6    7     Anil      M    Chennai   52000  Finance           7     4.3
# 7    8    Pooja      F       Pune   46000       IT           4     4.1
# 8    9    Vikas      M     Mumbai   60000       IT           8     4.6
# 9   10     Riya      F      Delhi   39000       HR           2     3.7
# 10  11   Deepak      M  Bangalore   75000  Finance          12     4.9
# 11  12    Meena      F    Chennai   47000       IT           5     4.2
# ...
